# %%
import pandas as pd

# %%
data = pd.read_csv("new_trail_info3.csv")

# %%
names = data["trail_name"]
# Out:
#        trail_id                                         trail_name  \
# 0      10029098                              Breakneck Ridge Trail
# 1      10016692                           Bear Mountain Loop Trail
# 2      10213388  Cascade Mountain and Porter Mountain via Casca...
# 3      10030730               Anthony's Nose via Appalachian Trail
# 4      10239145     Sleeping Beauty Mountain and Lake George Trail
# 5      10035049                            Overlook Mountain Trail
# 6      10019564                  Gorge Trail and Indian Trail Loop
# 7      10040629                            Kaaterskill Falls Trail
# 8      10033467                                 Mount Beacon Trail
# 9      10111549                              Hadley Mountain Trail
# 10     10030733               Mount Marcy via Van Hoevenberg Trail
# 11     10035044                              Gertrude's Nose Trail
# 12     10021374         Sam's Point and Verkeerderkill Falls Trail
# ...
